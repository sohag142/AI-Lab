# %%
graph = {
    '5' : ['3','7'],
    '3' : ['2', '4'],
    '7' : ['8'],
    '2' : [],
    '4' : ['8'],
    '8' : []
}
visited = []
queue = []

# %%
def dfs_iterative(graph, start_node):
  visited = set()
  stack = [start_node]

  while stack:
    node = stack.pop()
    if node not in visited:
      print (node)
      visited.add(node)
      for neighbour in graph[node]:
        stack.extend(reversed(graph[node]))

# %%
print("follwing")
dfs_iterative(graph, '5')
# Out:
# follwing
# 5
# 3
# 2
# 4
# 8
# 7

# %% [markdown]
# 1.Take some number form user find out the 2nd leargest number. [Rule: Do not use any building mathod apply logical process]
# 2.suppose you have 10 key with respected valu useing distance cost now apply bfs or dfs

# %%
graph = {
    'A' : ['B','C'],
    'B' : ['D','E'],
    'C' : ['F','I'],
    'D' : ['G',],
    'E' : ['G',],
    'F' : ['H',],
    'I' : [],
    'G' : ['H',],
    'H' : [],

    }
visited = []
queue = []

# %%
def bfs(visited, graph, node):
    visited.append(node)
    queue.append(node)
    while queue:
        m = queue.pop(0)
        print(m, end = " ")
        for neighbour in graph[m]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

# %%
print("Following")
bfs(visited, graph, 'A')
# Out:
# Following
# A B C D E F I G H

# %%
numbers = input("Enter number :").split()

nums = []
for n in numbers:
    nums.append(int(n))

largest = None
second_largest = None

for num in nums:
    if largest is None or num > largest:
        second_largest = largest
        largest = num
    elif num != largest:
        if second_largest is None or num > second_largest:
            second_largest = num

if second_largest is None:
    print("NOT FOUND")
else:
    print("The NUmber is :", second_largest)
# Out:
# Enter number :5 78 6 7 2
# The NUmber is : 7
